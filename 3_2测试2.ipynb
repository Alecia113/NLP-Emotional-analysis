# %% [markdown]
# <a href="https://colab.research.google.com/github/Alecia113/NLP-Emotional-analysis/blob/main/3_2%E6%B5%8B%E8%AF%952.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#要用语义，句法词关系来测试。[lab5-word_analogy_evaluation]
#https://colab.research.google.com/drive/1VdNkQpeI6iLPHeTsGe6sdHQFcGyV1Kmi?usp=sharing#scrollTo=EVk7tjwvhl-6

import numpy as np
import re
from lxml import etree 
import pprint
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize, sent_tokenize
from gensim.models import Word2Vec
import warnings
warnings.filterwarnings('ignore')
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)



id = '1B47OiEiG2Lo1jUY6hy_zMmHBxfKQuJ8-'
downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('ted_en-20160408.xml')  



#data preprocessing
targetXML=open('ted_en-20160408.xml', 'r', encoding='ISO-8859-1')
target_text = etree.parse(targetXML)
parse_text = '\n'.join(target_text.xpath('//content/text()'))
content_text = re.sub(r'\([^)]*\)', '', parse_text)
sent_text=sent_tokenize(content_text)

normalized_text = []
for string in sent_text:
     tokens = re.sub(r"[^a-z0-9]+", " ", string.lower())
     normalized_text.append(tokens)

sentences=[]
sentences=[word_tokenize(sentence) for sentence in normalized_text]

# Prints only 10 (tokenised) sentences
#print(sentences[:10])
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# #gensim word2vec #W2V-cbow
# wv_cbow_model = Word2Vec(sentences=sentences, size=100, window=5, min_count=5, workers=2, sg=0)
# wv_cbow_model.wv.save_word2vec_format('ted_cbow_w2v.txt', binary=False)
# vectors_wv_cbow="/content/ted_cbow_w2v.txt"    #打开训练好的文件。vectors_file

# #W2v-skip gram
# wv_sg_model = Word2Vec(sentences=sentences, size=100, window=5, min_count=5, workers=2, sg=1)
# wv_sg_model.wv.save_word2vec_format('ted_sg_w2v.txt', binary=False)
# vectors_wv_sg="/content/ted_sg_w2v.txt"    #打开训练好的文件。vectors_file

# #FastText- sg
# from gensim.models import FastText
# ft_sg_model = FastText(sentences=sentences, size=100, window=5, min_count=5, workers=2, sg=1)
# ft_sg_model.wv.save_word2vec_format('ted_sg_ft.txt', binary=False)
# vectors_ft_sg="/content/ted_sg_ft.txt"    #打开训练好的文件。vectors_file

# # fasttext - cbow
# ft_cbow_model = FastText(sentences=sentences, size=100, window=5, min_count=5, workers=2, sg=0)
# ft_cbow_model.wv.save_word2vec_format('ted_cbow_ft.txt', binary=False)
# vectors_ft_cbow="/content/ted_cbow_ft.txt"    #打开训练好的文件。vectors_file

# %%
#gensim word2vec #W2V-cbow
SIZE= 100
MIN_COUNT = 5
WINDOW = 5
wv_cbow_model = Word2Vec(sentences=sentences, size=SIZE, window=WINDOW, min_count=MIN_COUNT, workers=2, sg=0)
wv_cbow_model.wv.save_word2vec_format('ted_cbow_w2v.txt', binary=False)
vectors_wv_cbow="/content/ted_cbow_w2v.txt"    #打开训练好的文件。vectors_file

#W2v-skip gram
wv_sg_model = Word2Vec(sentences=sentences, size=SIZE, window=WINDOW, min_count=MIN_COUNT, workers=2, sg=1)
wv_sg_model.wv.save_word2vec_format('ted_sg_w2v.txt', binary=False)
vectors_wv_sg="/content/ted_sg_w2v.txt"    #打开训练好的文件。vectors_file

#FastText- sg
from gensim.models import FastText
ft_sg_model = FastText(sentences=sentences, size=SIZE, window=WINDOW, min_count=MIN_COUNT, workers=2, sg=1)
ft_sg_model.wv.save_word2vec_format('ted_sg_ft.txt', binary=False)
vectors_ft_sg="/content/ted_sg_ft.txt"    #打开训练好的文件。vectors_file

# fasttext - cbow
ft_cbow_model = FastText(sentences=sentences, size=SIZE, window=WINDOW, min_count=MIN_COUNT, workers=2, sg=0)
ft_cbow_model.wv.save_word2vec_format('ted_cbow_ft.txt', binary=False)
vectors_ft_cbow="/content/ted_cbow_ft.txt"    #打开训练好的文件。vectors_file

# %%
#匹配
def open_files(file_name):
  with open(file_name, 'r') as f:    #vectors_file == vectors_wv_cbow  ==file_name
    vectors = {}
    for line in f.readlines()[1:]: # we only need the embedding vectors starting from the second line 
      vals = line.rstrip().split(' ')
      vectors[vals[0]] = [x for x in vals[1:]]


  vocab_words=list(vectors.keys())
  vocab_size = len(vocab_words)
  print("Vocab size: ",str(vocab_size))

  # create word->index and index->word converter  
  vocab = {w: idx for idx, w in enumerate(vocab_words)} #每个单词对应个index
  ivocab = {idx: w for idx, w in enumerate(vocab_words)}  #每个index对应一个单词


  # create the embedding matrix of shape (vocab_size, dim)
  vector_dim = len(vectors[ivocab[0]])  #100
  W = np.zeros((vocab_size, vector_dim))    #4325.100
  for word, v in vectors.items():
      if word == '<unk>' or word == '':   #我加的
          continue
      
      W[vocab[word], :] = v   #100 102

  # normalize each word vector to unit length
  # Vectors are usually normalized to unit length before they are used for similarity calculation, making cosine similarity and dot-product equivalent.
  W_norm = np.zeros(W.shape)
  d = (np.sum(W ** 2, 1) ** (0.5))
  W_norm = (W.T / d).T
  
  return W, vocab, W_norm
#W, vocab

W1,vocab1,W1_norm = open_files(vectors_wv_cbow) #vectors_wv_sg  #vectors_ft_sg #vectors_ft_cbow
W2,vocab2,W2_norm = open_files(vectors_wv_sg) #vectors_wv_sg  #vectors_ft_sg #vectors_ft_cbow
W3,vocab3,W3_norm = open_files(vectors_ft_sg) #vectors_wv_sg  #vectors_ft_sg #vectors_ft_cbow
W4,vocab4,W4_norm = open_files(vectors_ft_cbow) #vectors_wv_sg  #vectors_ft_sg #vectors_ft_cbow
# Out:
# Vocab size:  21613
# Vocab size:  21613
# Vocab size:  21613
# Vocab size:  21613

# %%
#开始句法文本分析各种的功能语句。
# !git clone https://github.com/stanfordnlp/GloVe.git
def evaluate_vectors(W, vocab, prefix='./content/GloVe/eval/question-data/'):#/content/GloVe/eval/question-data
    """Evaluate the trained word vectors on a variety of tasks"""

    filenames = [
        'capital-common-countries.txt', 'capital-world.txt', 'currency.txt',
        'city-in-state.txt', 'family.txt', 'gram1-adjective-to-adverb.txt',
        'gram2-opposite.txt', 'gram3-comparative.txt', 'gram4-superlative.txt',
        'gram5-present-participle.txt', 'gram6-nationality-adjective.txt',
        'gram7-past-tense.txt', 'gram8-plural.txt', 'gram9-plural-verbs.txt',
        ]

    # to avoid memory overflow, could be increased/decreased
    # depending on system and vocab size
    split_size = 100

    correct_sem = 0; # count correct semantic questions  计算正确的语义问题
    correct_syn = 0; # count correct syntactic questions 计算正确的句法问题
    correct_tot = 0 # count correct questions   计算正确的问题
    count_sem = 0; # count all semantic questions 计算所有语义问题
    count_syn = 0; # count all syntactic questions  计算所有语法问题
    count_tot = 0 # count all questions   计算所有问题  
    full_count = 0 # count all questions, including those with unknown words    计算所有问题包括不知道n个单词的问题

    for i in range(len(filenames)):
        with open('%s/%s' % (prefix, filenames[i]), 'r') as f:
            full_data = [line.rstrip().split(' ') for line in f]
            full_count += len(full_data)
            data = [x for x in full_data if all(word in vocab for word in x)]

        if len(data) == 0:
            print("ERROR: no lines of vocab kept for %s !" % filenames[i])
            print("Example missing line:", full_data[0])
            continue

        indices = np.array([[vocab[word] for word in row] for row in data])
        ind1, ind2, ind3, ind4 = indices.T

        predictions = np.zeros((len(indices),))
        num_iter = int(np.ceil(len(indices) / float(split_size)))
        for j in range(num_iter):
            subset = np.arange(j*split_size, min((j + 1)*split_size, len(ind1)))

            pred_vec = (W[ind2[subset], :] - W[ind1[subset], :]
                +  W[ind3[subset], :])

            #cosine similarity if input W has been normalized
            dist = np.dot(W, pred_vec.T)


            for k in range(len(subset)):
                dist[ind1[subset[k]], k] = -np.Inf
                dist[ind2[subset[k]], k] = -np.Inf
                dist[ind3[subset[k]], k] = -np.Inf

            # predicted word index
            predictions[subset] = np.argmax(dist, 0).flatten()

        
        val = (ind4 == predictions) # correct predictions
        count_tot = count_tot + len(ind1) #216
        correct_tot = correct_tot + sum(val)
        if i < 5:
            count_sem = count_sem + len(ind1)
            correct_sem = correct_sem + sum(val)
        else:
            count_syn = count_syn + len(ind1)
            correct_syn = correct_syn + sum(val)

        print("%s:" % filenames[i])
        print('ACCURACY TOP1: %.2f%% (%d/%d)' %
            (np.mean(val) * 100, np.sum(val), len(val)))
        
    return correct_sem, correct_syn, correct_tot, count_sem, count_syn, count_tot, full_count
'''
#可视化展示
correct_sem, correct_syn, correct_tot, count_sem, count_syn, count_tot, full_count = evaluate_vectors(W_norm, vocab, prefix='/content/GloVe/eval/question-data')#/content/GloVe/eval/question-data
print('Questions seen/total: %.2f%% (%d/%d)' %    #看到的问题
    (100 * count_tot / float(full_count), count_tot, full_count))
print('Semantic accuracy: %.2f%%  (%i/%i)' %  #语义准确度 绿色的
    (100 * correct_sem / float(count_sem), correct_sem, count_sem))
print('Syntactic accuracy: %.2f%%  (%i/%i)' % #语法准确度 蓝色的
    (100 * correct_syn / float(count_syn), correct_syn, count_syn))
print('Total accuracy: %.2f%%  (%i/%i)' % (100 * correct_tot / float(count_tot), correct_tot, count_tot))
  #总准确度红线
'''
# Out:
# Cloning into 'GloVe'...
# remote: Enumerating objects: 595, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 595 (delta 0), reused 1 (delta 0), pack-reused 592
# Receiving objects: 100% (595/595), 222.33 KiB | 8.23 MiB/s, done.
# Resolving deltas: 100% (338/338), done.
# "\n#可视化展示\ncorrect_sem, correct_syn, correct_tot, count_sem, count_syn, count_tot, full_count = evaluate_vectors(W_norm, vocab, prefix='/content/GloVe/eval/question-data')#/content/GloVe/eval/question-data\nprint('Questions seen/total: %.2f%% (%d/%d)' %    #看到的问题\n    (100 * count_tot / float(full_count), count_tot, full_count))\nprint('Semantic accuracy: %.2f%%  (%i/%i)' %  #语义准确度 绿色的\n    (100 * correct_sem / float(count_sem), correct_sem, count_sem))\nprint('Syntactic accuracy: %.2f%%  (%i/%i)' % #语法准确度 蓝色的\n    (100 * correct_syn / float(count_syn), correct_syn, count_syn))\nprint('Total accuracy: %.2f%%  (%i/%i)' % (100 * correct_tot / float(count_tot), correct_tot, count_tot))\n  #总准确度红线\n"

# %%
# 1-vectors_wv_cbow； 2-vectors_wv_sg； 3-vectors_ft_sg； 4vectors_ft_cbow
def show_answer(W_norm,vocab):
  #可视化展示
  correct_sem, correct_syn, correct_tot, count_sem, count_syn, count_tot, full_count = evaluate_vectors(W_norm, vocab, prefix='/content/GloVe/eval/question-data')#/content/GloVe/eval/question-data
  Semantic = 100 * correct_sem / float(count_sem)
  Syntactic = 100 * correct_syn / float(count_syn)
  Total = 100 * correct_tot / float(count_tot)
  return Semantic, Syntactic, Total
  #overall
Semantic_wv_cbow, Syntactic_wv_cbow, Total_wv_cbow = show_answer(W1_norm, vocab1)
print(Total_wv_cbow)
print('\n')
Semantic_wv_sg, Syntactic_wv_sg, Total_wv_sg = show_answer(W2_norm, vocab2)
print(Total_wv_sg)
print('\n')
Semantic_ft_sg, Syntactic_ft_sg, Total_ft_sg = show_answer(W3_norm, vocab3)
print(Total_ft_sg)
print('\n')
Semantic_ft_cbow, Syntactic_ft_cbow, Total_ft_cbow = show_answer(W4_norm, vocab4)
print(Total_ft_cbow)
# Out:
# capital-common-countries.txt:
# ACCURACY TOP1: 5.88% (16/272)
# capital-world.txt:
# ACCURACY TOP1: 4.54% (23/507)
# currency.txt:
# ACCURACY TOP1: 0.00% (0/28)
# city-in-state.txt:
# ACCURACY TOP1: 1.47% (8/545)
# family.txt:
# ACCURACY TOP1: 45.61% (156/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 1.97% (16/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 0.99% (5/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 32.66% (435/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 10.58% (80/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 33.87% (336/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 3.77% (32/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 23.75% (352/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 15.48% (144/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 16.80% (127/756)
# 17.1134632505688
#
#
# capital-common-countries.txt:
# ACCURACY TOP1: 3.31% (9/272)
# capital-world.txt:
# ACCURACY TOP1: 2.17% (11/507)
# currency.txt:
# ACCURACY TOP1: 0.00% (0/28)
# city-in-state.txt:
# ACCURACY TOP1: 2.75% (15/545)
# family.txt:
# ACCURACY TOP1: 43.86% (150/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 4.93% (40/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 1.98% (10/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 37.61% (501/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 16.27% (123/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 36.69% (364/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 3.18% (27/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 21.52% (319/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 23.66% (220/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 19.58% (148/756)
# 19.16114353546345
#
#
# capital-common-countries.txt:
# ACCURACY TOP1: 1.10% (3/272)
# capital-world.txt:
# ACCURACY TOP1: 1.97% (10/507)
# currency.txt:
# ACCURACY TOP1: 0.00% (0/28)
# city-in-state.txt:
# ACCURACY TOP1: 2.94% (16/545)
# family.txt:
# ACCURACY TOP1: 41.81% (143/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 79.06% (642/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 83.79% (424/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 78.60% (1047/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 89.42% (676/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 81.55% (809/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 39.81% (338/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 36.23% (537/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 69.46% (646/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 76.98% (582/756)
# 58.09674547432981
#
#
# capital-common-countries.txt:
# ACCURACY TOP1: 0.74% (2/272)
# capital-world.txt:
# ACCURACY TOP1: 1.38% (7/507)
# currency.txt:
# ACCURACY TOP1: 0.00% (0/28)
# city-in-state.txt:
# ACCURACY TOP1: 0.00% (0/545)
# family.txt:
# ACCURACY TOP1: 20.18% (69/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 71.55% (581/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 87.15% (441/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 77.78% (1036/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 88.10% (666/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 65.83% (653/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 19.32% (164/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 18.22% (270/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 53.33% (496/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 71.69% (542/756)
# 48.73874765060837

# %%
SIZE= 100
MIN_COUNT = 5
WINDOW = 5

# %%
#table
from prettytable import PrettyTable
x = PrettyTable(['Model','Size','Window','Min_count','|','Sem','Syn','Tot'])
x.align['Model'] = '1' #以model字段左对齐
x.padding_width = 1 #填充快读
x.add_row(['W2V_cbow','100','5','5','|',Semantic_wv_cbow, Syntactic_wv_cbow, Total_wv_cbow])
x.add_row(['W2V_sg  ','100','5','5','|',Semantic_wv_sg, Syntactic_wv_sg, Total_wv_sg])
x.add_row(['Ft_sg   ','100','5','5','|',Semantic_ft_sg, Syntactic_ft_sg, Total_ft_sg])
x.add_row(['Ft_cbow ','100','5','5','|',Semantic_ft_cbow, Syntactic_ft_cbow, Total_ft_cbow])
print(x)
# Out:
# +----------+------+--------+-----------+---+--------------------+--------------------+-------------------+
# |  Model   | Size | Window | Min_count | | |        Sem         |        Syn         |        Tot        |
# +----------+------+--------+-----------+---+--------------------+--------------------+-------------------+
# | W2V_cbow | 100  |   5    |     5     | | | 11.983471074380166 | 18.146167557932262 |  17.1134632505688 |
# | W2V_sg   | 100  |   5    |     5     | | | 10.920897284533648 | 20.819964349376114 | 19.16114353546345 |
# | Ft_sg    | 100  |   5    |     5     | | | 10.153482880755607 | 67.74806892453951  | 58.09674547432981 |
# | Ft_cbow  | 100  |   5    |     5     | | | 4.6044864226682405 |  57.6232917409388  | 48.73874765060837 |
# +----------+------+--------+-----------+---+--------------------+--------------------+-------------------+

# %%
#Ft_sg 2h
def size_change(name, sgn):
  size = [100,200,300,400,500,600] #x
  MIN_COUNT = 5
  WINDOW = 10
  Sem_test = []
  Syn_test = []
  Tot_test = []
  for s_size in range(len(size)):
    SIZE = size[s_size]
    size_change = name(sentences=sentences, size=SIZE, window=WINDOW, min_count=MIN_COUNT, workers=2, sg = sgn) #FastText
    size_change.wv.save_word2vec_format('size_change.txt', binary=False)
    vectors="/content/size_change.txt"    #打开训练好的文件。vectors_file

    W_test,vocab_test,W_test_norm = open_files(vectors)
    Semantic_test, Syntactic_test, Total_test = show_answer(W_test_norm, vocab_test)
    Sem_test.append(Semantic_test)
    Syn_test.append(Syntactic_test)
    Tot_test.append(Total_test)
  return Sem_test, Syn_test, Tot_test


#Sem_ftsg, Syn_ftsg, Tot_ftsy = size_change(FastText,1)


# print(Sem_ftsg)
# print(Syn_ftsg)
# print(Tot_ftsg) 
#y=accuary
#1多h

# %%
Sem_ftsg, Syn_ftsg, Tot_ftsy = size_change(FastText,1)
# Out:
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 1.10% (3/272)
# capital-world.txt:
# ACCURACY TOP1: 2.56% (13/507)
# currency.txt:
# ACCURACY TOP1: 0.00% (0/28)
# city-in-state.txt:
# ACCURACY TOP1: 1.47% (8/545)
# family.txt:
# ACCURACY TOP1: 31.87% (109/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 70.32% (571/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 76.48% (387/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 78.00% (1039/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 85.85% (649/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 78.43% (778/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 47.23% (401/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 35.36% (524/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 70.43% (655/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 71.16% (538/756)
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 1.84% (5/272)
# capital-world.txt:
# ACCURACY TOP1: 2.56% (13/507)
# currency.txt:
# ACCURACY TOP1: 3.57% (1/28)
# city-in-state.txt:
# ACCURACY TOP1: 3.12% (17/545)
# family.txt:
# ACCURACY TOP1: 32.46% (111/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 79.93% (649/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 84.39% (427/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 81.08% (1080/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 90.48% (684/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 77.82% (772/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 53.95% (458/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 35.29% (523/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 73.98% (688/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 77.91% (589/756)
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 1.84% (5/272)
# capital-world.txt:
# ACCURACY TOP1: 1.97% (10/507)
# currency.txt:
# ACCURACY TOP1: 3.57% (1/28)
# city-in-state.txt:
# ACCURACY TOP1: 3.30% (18/545)
# family.txt:
# ACCURACY TOP1: 25.15% (86/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 75.99% (617/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 86.56% (438/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 82.06% (1093/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 91.93% (695/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 80.44% (798/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 56.30% (478/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 34.62% (513/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 73.33% (682/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 80.16% (606/756)
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 0.37% (1/272)
# capital-world.txt:
# ACCURACY TOP1: 2.37% (12/507)
# currency.txt:
# ACCURACY TOP1: 0.00% (0/28)
# city-in-state.txt:
# ACCURACY TOP1: 2.57% (14/545)
# family.txt:
# ACCURACY TOP1: 29.24% (100/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 79.06% (642/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 85.77% (434/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 81.31% (1083/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 92.06% (696/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 77.82% (772/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 53.71% (456/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 36.30% (538/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 72.26% (672/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 79.89% (604/756)
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 0.74% (2/272)
# capital-world.txt:
# ACCURACY TOP1: 2.17% (11/507)
# currency.txt:
# ACCURACY TOP1: 0.00% (0/28)
# city-in-state.txt:
# ACCURACY TOP1: 2.39% (13/545)
# family.txt:
# ACCURACY TOP1: 27.49% (94/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 81.90% (665/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 86.36% (437/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 80.03% (1066/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 92.06% (696/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 77.72% (771/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 56.07% (476/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 36.50% (541/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 71.94% (669/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 81.22% (614/756)
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 1.47% (4/272)
# capital-world.txt:
# ACCURACY TOP1: 2.17% (11/507)
# currency.txt:
# ACCURACY TOP1: 3.57% (1/28)
# city-in-state.txt:
# ACCURACY TOP1: 2.94% (16/545)
# family.txt:
# ACCURACY TOP1: 25.44% (87/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 79.06% (642/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 86.96% (440/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 82.06% (1093/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 91.01% (688/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 78.43% (778/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 53.95% (458/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 35.36% (524/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 74.09% (689/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 78.84% (596/756)

# %%
Sem_ftcb, Syn_ftcb, Tot_ftcb = size_change(FastText,0)
# Out:
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 1.47% (4/272)
# capital-world.txt:
# ACCURACY TOP1: 0.99% (5/507)
# currency.txt:
# ACCURACY TOP1: 3.57% (1/28)
# city-in-state.txt:
# ACCURACY TOP1: 0.00% (0/545)
# family.txt:
# ACCURACY TOP1: 15.20% (52/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 73.52% (597/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 82.81% (419/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 75.00% (999/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 86.11% (651/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 67.94% (674/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 21.44% (182/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 19.50% (289/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 52.58% (489/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 73.02% (552/756)
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 1.10% (3/272)
# capital-world.txt:
# ACCURACY TOP1: 1.38% (7/507)
# currency.txt:
# ACCURACY TOP1: 3.57% (1/28)
# city-in-state.txt:
# ACCURACY TOP1: 0.00% (0/545)
# family.txt:
# ACCURACY TOP1: 13.45% (46/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 72.41% (588/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 85.57% (433/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 77.63% (1034/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 86.90% (657/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 68.45% (679/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 20.14% (171/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 19.64% (291/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 51.40% (478/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 71.69% (542/756)
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 0.37% (1/272)
# capital-world.txt:
# ACCURACY TOP1: 0.39% (2/507)
# currency.txt:
# ACCURACY TOP1: 3.57% (1/28)
# city-in-state.txt:
# ACCURACY TOP1: 0.00% (0/545)
# family.txt:
# ACCURACY TOP1: 15.20% (52/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 72.17% (586/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 84.98% (430/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 79.20% (1055/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 86.77% (656/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 69.25% (687/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 19.08% (162/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 19.43% (288/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 51.72% (481/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 72.09% (545/756)
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 0.74% (2/272)
# capital-world.txt:
# ACCURACY TOP1: 0.79% (4/507)
# currency.txt:
# ACCURACY TOP1: 3.57% (1/28)
# city-in-state.txt:
# ACCURACY TOP1: 0.00% (0/545)
# family.txt:
# ACCURACY TOP1: 17.25% (59/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 70.57% (573/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 87.15% (441/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 78.08% (1040/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 87.83% (664/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 69.05% (685/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 19.08% (162/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 19.64% (291/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 51.08% (475/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 71.69% (542/756)
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 0.74% (2/272)
# capital-world.txt:
# ACCURACY TOP1: 0.59% (3/507)
# currency.txt:
# ACCURACY TOP1: 3.57% (1/28)
# city-in-state.txt:
# ACCURACY TOP1: 0.00% (0/545)
# family.txt:
# ACCURACY TOP1: 14.33% (49/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 72.66% (590/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 86.36% (437/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 76.80% (1023/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 86.11% (651/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 66.73% (662/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 20.61% (175/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 18.89% (280/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 53.87% (501/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 71.30% (539/756)
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 0.74% (2/272)
# capital-world.txt:
# ACCURACY TOP1: 0.99% (5/507)
# currency.txt:
# ACCURACY TOP1: 3.57% (1/28)
# city-in-state.txt:
# ACCURACY TOP1: 0.00% (0/545)
# family.txt:
# ACCURACY TOP1: 16.08% (55/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 71.80% (583/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 87.15% (441/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 76.73% (1022/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 87.04% (658/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 71.47% (709/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 20.26% (172/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 19.43% (288/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 51.83% (482/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 71.43% (540/756)

# %%
Sem_wvcb, Syn_wvcb, Tot_wvcb = size_change(FastText,0)
# Out:
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 0.74% (2/272)
# capital-world.txt:
# ACCURACY TOP1: 0.79% (4/507)
# currency.txt:
# ACCURACY TOP1: 0.00% (0/28)
# city-in-state.txt:
# ACCURACY TOP1: 0.18% (1/545)
# family.txt:
# ACCURACY TOP1: 14.04% (48/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 68.84% (559/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 85.77% (434/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 76.58% (1020/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 87.17% (659/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 67.24% (667/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 19.79% (168/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 19.43% (288/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 52.15% (485/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 72.35% (547/756)
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 0.74% (2/272)
# capital-world.txt:
# ACCURACY TOP1: 0.99% (5/507)
# currency.txt:
# ACCURACY TOP1: 3.57% (1/28)
# city-in-state.txt:
# ACCURACY TOP1: 0.18% (1/545)
# family.txt:
# ACCURACY TOP1: 14.91% (51/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 72.78% (591/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 85.38% (432/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 78.53% (1046/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 87.30% (660/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 70.06% (695/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 20.73% (176/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 19.91% (295/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 52.90% (492/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 70.63% (534/756)
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 0.74% (2/272)
# capital-world.txt:
# ACCURACY TOP1: 0.20% (1/507)
# currency.txt:
# ACCURACY TOP1: 3.57% (1/28)
# city-in-state.txt:
# ACCURACY TOP1: 0.00% (0/545)
# family.txt:
# ACCURACY TOP1: 16.37% (56/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 71.31% (579/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 84.58% (428/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 76.80% (1023/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 86.90% (657/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 69.05% (685/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 18.61% (158/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 18.69% (277/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 52.04% (484/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 71.43% (540/756)
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 0.74% (2/272)
# capital-world.txt:
# ACCURACY TOP1: 0.79% (4/507)
# currency.txt:
# ACCURACY TOP1: 3.57% (1/28)
# city-in-state.txt:
# ACCURACY TOP1: 0.00% (0/545)
# family.txt:
# ACCURACY TOP1: 14.91% (51/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 71.67% (582/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 85.18% (431/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 76.95% (1025/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 86.64% (655/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 67.74% (672/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 19.55% (166/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 19.50% (289/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 52.04% (484/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 72.09% (545/756)
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 1.10% (3/272)
# capital-world.txt:
# ACCURACY TOP1: 0.79% (4/507)
# currency.txt:
# ACCURACY TOP1: 3.57% (1/28)
# city-in-state.txt:
# ACCURACY TOP1: 0.00% (0/545)
# family.txt:
# ACCURACY TOP1: 16.08% (55/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 69.95% (568/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 85.77% (434/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 77.93% (1038/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 86.90% (657/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 68.65% (681/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 21.55% (183/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 18.96% (281/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 53.01% (493/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 72.49% (548/756)
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 0.74% (2/272)
# capital-world.txt:
# ACCURACY TOP1: 0.59% (3/507)
# currency.txt:
# ACCURACY TOP1: 0.00% (0/28)
# city-in-state.txt:
# ACCURACY TOP1: 0.18% (1/545)
# family.txt:
# ACCURACY TOP1: 15.79% (54/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 69.70% (566/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 86.56% (438/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 77.33% (1030/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 86.64% (655/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 66.13% (656/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 20.73% (176/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 18.83% (279/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 52.37% (487/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 71.43% (540/756)

# %%
Sem_wvsg, Syn_wvsg, Tot_wvsy = size_change(FastText,1)
# Out:
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 1.84% (5/272)
# capital-world.txt:
# ACCURACY TOP1: 2.37% (12/507)
# currency.txt:
# ACCURACY TOP1: 0.00% (0/28)
# city-in-state.txt:
# ACCURACY TOP1: 2.39% (13/545)
# family.txt:
# ACCURACY TOP1: 35.09% (120/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 74.51% (605/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 77.27% (391/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 79.58% (1060/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 87.83% (664/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 81.35% (807/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 46.64% (396/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 39.14% (580/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 70.54% (656/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 70.77% (535/756)
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 1.10% (3/272)
# capital-world.txt:
# ACCURACY TOP1: 1.97% (10/507)
# currency.txt:
# ACCURACY TOP1: 0.00% (0/28)
# city-in-state.txt:
# ACCURACY TOP1: 2.20% (12/545)
# family.txt:
# ACCURACY TOP1: 26.02% (89/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 77.96% (633/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 85.38% (432/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 82.58% (1100/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 93.12% (704/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 79.44% (788/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 56.77% (482/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 34.89% (517/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 71.40% (664/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 79.50% (601/756)
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 1.47% (4/272)
# capital-world.txt:
# ACCURACY TOP1: 2.17% (11/507)
# currency.txt:
# ACCURACY TOP1: 0.00% (0/28)
# city-in-state.txt:
# ACCURACY TOP1: 3.12% (17/545)
# family.txt:
# ACCURACY TOP1: 26.02% (89/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 78.45% (637/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 87.55% (443/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 81.01% (1079/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 91.14% (689/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 80.24% (796/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 54.06% (459/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 36.37% (539/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 74.09% (689/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 80.42% (608/756)
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 1.10% (3/272)
# capital-world.txt:
# ACCURACY TOP1: 2.17% (11/507)
# currency.txt:
# ACCURACY TOP1: 3.57% (1/28)
# city-in-state.txt:
# ACCURACY TOP1: 3.30% (18/545)
# family.txt:
# ACCURACY TOP1: 25.44% (87/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 80.91% (657/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 86.36% (437/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 81.83% (1090/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 93.39% (706/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 78.83% (782/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 49.35% (419/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 34.82% (516/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 75.59% (703/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 80.42% (608/756)
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 1.10% (3/272)
# capital-world.txt:
# ACCURACY TOP1: 2.17% (11/507)
# currency.txt:
# ACCURACY TOP1: 0.00% (0/28)
# city-in-state.txt:
# ACCURACY TOP1: 2.57% (14/545)
# family.txt:
# ACCURACY TOP1: 26.90% (92/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 80.30% (652/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 86.17% (436/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 81.53% (1086/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 92.99% (703/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 80.95% (803/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 53.71% (456/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 34.89% (517/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 74.30% (691/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 80.82% (611/756)
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 1.10% (3/272)
# capital-world.txt:
# ACCURACY TOP1: 1.97% (10/507)
# currency.txt:
# ACCURACY TOP1: 3.57% (1/28)
# city-in-state.txt:
# ACCURACY TOP1: 1.47% (8/545)
# family.txt:
# ACCURACY TOP1: 30.12% (103/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 82.39% (669/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 86.17% (436/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 80.93% (1078/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 91.93% (695/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 80.24% (796/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 55.59% (472/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 35.16% (521/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 71.94% (669/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 80.29% (607/756)

# %%
SIZE
# Out:
# 100

# %%
# #gensim word2vec #W2V-cbow
# SIZE= 100
# MIN_COUNT = 5
# WINDOW = 5
# wv_cbow_model = Word2Vec(sentences=sentences, size=SIZE, window=WINDOW, min_count=MIN_COUNT, workers=2, sg=0)
# wv_cbow_model.wv.save_word2vec_format('ted_cbow_w2v.txt', binary=False)
# vectors_wv_cbow="/content/ted_cbow_w2v.txt"    #打开训练好的文件。vectors_file

# #W2v-skip gram
# wv_sg_model = Word2Vec(sentences=sentences, size=SIZE, window=WINDOW, min_count=MIN_COUNT, workers=2, sg=1)
# wv_sg_model.wv.save_word2vec_format('ted_sg_w2v.txt', binary=False)
# vectors_wv_sg="/content/ted_sg_w2v.txt"    #打开训练好的文件。vectors_file

# #FastText- sg
# from gensim.models import FastText
# ft_sg_model = FastText(sentences=sentences, size=SIZE, window=WINDOW, min_count=MIN_COUNT, workers=2, sg=1)
# ft_sg_model.wv.save_word2vec_format('ted_sg_ft.txt', binary=False)
# vectors_ft_sg="/content/ted_sg_ft.txt"    #打开训练好的文件。vectors_file

# # fasttext - cbow
# ft_cbow_model = FastText(sentences=sentences, size=SIZE, window=WINDOW, min_count=MIN_COUNT, workers=2, sg=0)
# ft_cbow_model.wv.save_word2vec_format('ted_cbow_ft.txt', binary=False)
# vectors_ft_cbow="/content/ted_cbow_ft.txt"    #打开训练好的文件。vectors_file

# %%
#Ft_sg 2h
'''
第一个图：window = 10； size【0-600】（x） 把后三个准确率是y  【0，100,200,300,400,500,600]
第二个图：size = 100 ； window【2-10】 [2.4.6,8,10]
第三个图没get到。
'''
'''
size = [100,200,300,400,500,600] #x
MIN_COUNT = 5
WINDOW = 10
Sem_ftsg = []
Syn_ftsg = []
Tot_ftsg = []
for s_size in range(len(size)):
  SIZE = size[s_size]
  test_ftsg = FastText(sentences=sentences, size=SIZE, window=WINDOW, min_count=MIN_COUNT, workers=2, sg=1)
  test_ftsg.wv.save_word2vec_format('test_ftsg.txt', binary=False)
  vectors_ftsg="/content/test_ftsg.txt"    #打开训练好的文件。vectors_file

  W_test,vocab_test,W_test_norm = open_files(vectors_ftsg)
  Semantic_ftsg, Syntactic_ftsg, Total_ftsg = show_answer(W_test_norm, vocab_test)
  Sem_ftsg.append(Semantic_ftsg)
  Syn_ftsg.append(Syntactic_ftsg)
  Tot_ftsg.append(Total_ftsg)
print(Sem_ftsg)
print(Syn_ftsg)
print(Tot_ftsg)
#y=accuary
#1多h
'''
# Out:
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 0.74% (2/272)
# capital-world.txt:
# ACCURACY TOP1: 1.58% (8/507)
# currency.txt:
# ACCURACY TOP1: 3.57% (1/28)
# city-in-state.txt:
# ACCURACY TOP1: 2.57% (14/545)
# family.txt:
# ACCURACY TOP1: 26.90% (92/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 80.05% (650/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 88.54% (448/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 80.86% (1077/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 93.25% (705/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 79.44% (788/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 57.24% (486/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 35.76% (530/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 73.76% (686/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 80.56% (609/756)
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 0.74% (2/272)
# capital-world.txt:
# ACCURACY TOP1: 1.58% (8/507)
# currency.txt:
# ACCURACY TOP1: 0.00% (0/28)
# city-in-state.txt:
# ACCURACY TOP1: 2.20% (12/545)
# family.txt:
# ACCURACY TOP1: 26.90% (92/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 81.16% (659/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 86.36% (437/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 80.63% (1074/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 90.87% (687/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 79.94% (793/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 51.83% (440/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 34.35% (509/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 71.94% (669/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 77.91% (589/756)
# [8.85478158205431, 7.556080283353011, 7.083825265643448, 7.792207792207792, 6.906729634002361, 6.7296340023612755]
# [66.95187165775401, 70.5050505050505, 70.42186571598336, 71.15864527629233, 71.05169340463458, 69.60190136660725]
# [57.216341873578, 59.95647442872688, 59.80809179938669, 60.540112770798295, 60.30270056385399, 59.06617865268573]

# %%
import matplotlib.pyplot as plt
import time
#等差数列。
x = [100,200,300,400,500,600]  #100-600
y1 = [Semantic for Semantic in Sem_ftsg]
y2 = [Syntactic for Syntactic in Syn_ftsg]
y3 = [Total for Total in Tot_ftsg]
plt.plot(x,y1,'rs-',markersize =5,label = 'Semantic')
plt.plot(x,y2,'m-',markersize =5,label = 'Syntactic')
plt.plot(x,y3,'k-',markersize =5,label = 'Total')
plt.xlabel('Vector Size(Dimension)')
plt.ylabel('Accuracy[%]')
plt.title('The relationship between word vectors and semantics')
plt.legend()
plt.show()

print(time.process_time()) # 返回进程运行时间
# Out:
# 8089.492671243

# %% [markdown]
# size变 window没变

# %%
Sem_wvsg, Syn_wvsg, Tot_wvsy = size_change(FastText,1)

Sem_ftsg, Syn_ftsg, Tot_ftsy = size_change(FastText,1)
Sem_ftcb, Syn_ftcb, Tot_ftcb = size_change(FastText,0)
Sem_wvcb, Syn_wvcb, Tot_wvcb = size_change(FastText,0)

# %%
def appdd(name1,name2,name3):
  l1 = [0]
  l2 = [0]
  l3 = [0]
  for i in range(6):
    l1.append(name1[i])
    l2.append(name2[i])
    l3.append(name3[i])
  return l1, l2, l3

l1, l2, l3 = appdd(Sem_ftsg,Syn_ftsg,Tot_ftsy)

# %%
l4, l5, l6 = appdd(Sem_wvsg,Syn_wvsg,Tot_wvsy)

# %%
l7, l8, l9 = appdd(Sem_ftcb,Syn_ftcb,Tot_ftcb)

# %%
l10, l11, l12 = appdd(Sem_wvcb,Syn_wvcb,Tot_wvcb)

# %%
x = [100,200,300,400,500,600]  #100-600
y1 = [Semantic for Semantic in Sem_ftsg]
y2 = [Syntactic for Syntactic in Syn_ftsg]
y3 = [Total for Total in Tot_ftsg]

# %%
import matplotlib.pyplot as plt
#等差数列。
x = [0,100,200,300,400,500,600]  #7
ys1 = [Semantic for Semantic in l1]
ys2 = [Syntactic for Syntactic in l2]
ys3 = [Total for Total in l3]
plt.plot(x,ys1,'rs-',markersize =5,label = 'Semantic_ftsg')
plt.plot(x,ys2,'m-',markersize =5,label = 'Syntactic_ftsg')
plt.plot(x,ys3,'k-',markersize =5,label = 'Total_ftsg')
ys4 = [Semantic for Semantic in l4]
ys5 = [Syntactic for Syntactic in l5]
ys6 = [Total for Total in l6]
plt.plot(x,ys4,'g-',markersize =5,label = 'Semantic_wvsg')
plt.plot(x,ys5,'p-',markersize =5,label = 'Syntactic_wvsg')
plt.plot(x,ys6,'y-',markersize =5,label = 'Total_wvsg')

ys7= [Semantic for Semantic in l7]
ys8 = [Syntactic for Syntactic in l8]
ys9 = [Total for Total in l9]
plt.plot(x,ys7,'o-',markersize =5,label = 'Semantic_ftcb')
plt.plot(x,ys8,'b-',markersize =5,label = 'Syntactic_ftcb')
plt.plot(x,ys9,'#FFB6C1',markersize =5,label = 'Total_ftcb')

ys10 = [Semantic for Semantic in l10]
ys11 = [Syntactic for Syntactic in l11]
ys12 = [Total for Total in l12]
plt.plot(x,ys10,'#B22222',markersize =5,label = 'Semantic_wvcb')
plt.plot(x,ys11,'#00FF00',markersize =5,label = 'Syntactic_wvcb')
plt.plot(x,ys12,'#0000CD',markersize =5,label = 'Total_wvcb')

plt.ylabel('Accuracy[%]')
plt.title('The relationship between word vectors and semantics')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
#等差数列。
x = [0,100,200,300,400,500,600]  #7
ys1 = [Semantic for Semantic in l1]
ys2 = [Syntactic for Syntactic in l2]
ys3 = [Total for Total in l3]
plt.plot(x,ys1,'rs-',markersize =5,label = 'Semantic_ftsg')
plt.plot(x,ys2,'m-',markersize =5,label = 'Syntactic_ftsg')
plt.plot(x,ys3,'k-',markersize =5,label = 'Total_ftsg')


plt.ylabel('Accuracy[%]')
plt.title('The relationship between word vectors and semantics')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
#等差数列。
x = [0,100,200,300,400,500,600]  #7
ys4 = [Semantic for Semantic in l4]
ys5 = [Syntactic for Syntactic in l5]
ys6 = [Total for Total in l6]
plt.plot(x,ys4,'g-',markersize =5,label = 'Semantic_wvsg')
plt.plot(x,ys5,'p-',markersize =5,label = 'Syntactic_wvsg')
plt.plot(x,ys6,'y-',markersize =5,label = 'Total_wvsg')


plt.ylabel('Accuracy[%]')
plt.title('The relationship between word vectors and semantics')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
#等差数列。
x = [0,100,200,300,400,500,600]  #7

ys7= [Semantic for Semantic in l7]
ys8 = [Syntactic for Syntactic in l8]
ys9 = [Total for Total in l9]
plt.plot(x,ys7,'o-',markersize =5,label = 'Semantic_ftcb')
plt.plot(x,ys8,'b-',markersize =5,label = 'Syntactic_ftcb')
plt.plot(x,ys9,'#FFB6C1',markersize =5,label = 'Total_ftcb')

plt.ylabel('Accuracy[%]')
plt.title('The relationship between word vectors and semantics')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
#等差数列。
x = [0,100,200,300,400,500,600]  #7


ys10 = [Semantic for Semantic in l10]
ys11 = [Syntactic for Syntactic in l11]
ys12 = [Total for Total in l12]
plt.plot(x,ys10,'#B22222',markersize =5,label = 'Semantic_wvcb')
plt.plot(x,ys11,'#00FF00',markersize =5,label = 'Syntactic_wvcb')
plt.plot(x,ys12,'#0000CD',markersize =5,label = 'Total_wvcb')

plt.ylabel('Accuracy[%]')
plt.title('The relationship between word vectors and semantics')
plt.legend()
plt.show()

# %% [markdown]
# Window size变  size 不变

# %%
#Ft_sg
'''
第一个图：window = 10； size【0-600】（x） 把后三个准确率是y  【0，100,200,300,400,500,600]
第二个图：size = 100 ； window【2-10】 [2.4.6,8,10]
第三个图没get到。
'''
since = time.time()
def win_change(name,sgn):
  SIZE = 100 #x
  MIN_COUNT = 5
  WINDOW = [2,4,6,8,10]
  Sem_win = []
  Syn_win = []
  Tot_win = []
  for win in range(len(WINDOW)):
    WINDOW = size[win]
    test_win = name(sentences=sentences, size=SIZE, window=WINDOW, min_count=MIN_COUNT, workers=2, sg=sgn)
    test_win.wv.save_word2vec_format('test_win.txt', binary=False)
    vectors_win="/content/test_win.txt"    #打开训练好的文件。vectors_file

    W_test,vocab_test,W_test_norm = open_files(vectors_win)
    Semantic_win, Syntactic_win, Total_win= show_answer(W_test_norm, vocab_test)
    Sem_win.append(Semantic_win)
    Syn_win.append(Syntactic_win)
    Tot_win.append(Total_win)
  
  return Sem_win, Syn_win, Tot_win

  
# print(Sem_win_ftsg)
# print(Syn_win_ftsg)
# print(Tot_win_ftsg)
time_elapsed = time.time() - since
print('The code run {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
#y=accuary

# %%
#运行。
Sem_win_ftsg, Syn_win_ftsg, Tot_win_ftsy = size_change(FastText,1)
Sem_win_ftcb, Syn_win_ftcb, Tot_win_ftcb = size_change(FastText,0)
Sem_win_wvcb, Syn_win_wvcb, Tot_win_wvcb = size_change(FastText,0)
Sem_win_wvsg, Syn_win_wvsg, Tot_win_wvsy = size_change(FastText,1)

# %%
#Ft_sg
'''
第一个图：window = 10； size【0-600】（x） 把后三个准确率是y  【0，100,200,300,400,500,600]
第二个图：size = 100 ； window【2-10】 [2.4.6,8,10]
第三个图没get到。
'''
'''
since = time.time()

SIZE = 100 #x
MIN_COUNT = 5
WINDOW = [2,4,6,8,10]
Sem_win_ftsg = []
Syn_win_ftsg = []
Tot_win_ftsg = []
for win in range(len(WINDOW)):
  WINDOW = size[win]
  test_ftsg = FastText(sentences=sentences, size=SIZE, window=WINDOW, min_count=MIN_COUNT, workers=2, sg=1)
  test_ftsg.wv.save_word2vec_format('test_ftsg.txt', binary=False)
  vectors_ftsg="/content/test_ftsg.txt"    #打开训练好的文件。vectors_file

  W_test,vocab_test,W_test_norm = open_files(vectors_ftsg)
  Semantic_ftsg, Syntactic_ftsg, Total_ftsg = show_answer(W_test_norm, vocab_test)
  Sem_win_ftsg.append(Semantic_ftsg)
  Syn_win_ftsg.append(Syntactic_ftsg)
  Tot_win_ftsg.append(Total_ftsg)
print(Sem_win_ftsg)
print(Syn_win_ftsg)
print(Tot_win_ftsg)
time_elapsed = time.time() - since
print('The code run {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
#y=accuary
'''
# Out:
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 6.62% (18/272)
# capital-world.txt:
# ACCURACY TOP1: 3.94% (20/507)
# currency.txt:
# ACCURACY TOP1: 0.00% (0/28)
# city-in-state.txt:
# ACCURACY TOP1: 2.57% (14/545)
# family.txt:
# ACCURACY TOP1: 25.44% (87/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 57.76% (469/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 59.29% (300/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 61.94% (825/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 67.46% (510/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 70.06% (695/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 50.65% (430/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 34.55% (512/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 67.74% (630/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 57.80% (437/756)
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 5.88% (16/272)
# capital-world.txt:
# ACCURACY TOP1: 3.75% (19/507)
# currency.txt:
# ACCURACY TOP1: 0.00% (0/28)
# city-in-state.txt:
# ACCURACY TOP1: 1.65% (9/545)
# family.txt:
# ACCURACY TOP1: 23.98% (82/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 55.17% (448/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 62.25% (315/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 60.21% (802/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 68.12% (515/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 69.05% (685/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 52.06% (442/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 38.39% (569/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 70.11% (652/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 57.01% (431/756)
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 5.88% (16/272)
# capital-world.txt:
# ACCURACY TOP1: 4.54% (23/507)
# currency.txt:
# ACCURACY TOP1: 0.00% (0/28)
# city-in-state.txt:
# ACCURACY TOP1: 1.47% (8/545)
# family.txt:
# ACCURACY TOP1: 26.90% (92/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 57.51% (467/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 57.71% (292/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 60.51% (806/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 60.85% (460/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 65.32% (648/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 53.12% (451/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 34.68% (514/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 71.94% (669/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 57.67% (436/756)
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 5.51% (15/272)
# capital-world.txt:
# ACCURACY TOP1: 3.94% (20/507)
# currency.txt:
# ACCURACY TOP1: 0.00% (0/28)
# city-in-state.txt:
# ACCURACY TOP1: 1.47% (8/545)
# family.txt:
# ACCURACY TOP1: 28.95% (99/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 54.31% (441/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 58.50% (296/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 60.89% (811/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 61.38% (464/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 69.05% (685/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 53.71% (456/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 32.12% (476/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 69.46% (646/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 56.08% (424/756)
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 4.78% (13/272)
# capital-world.txt:
# ACCURACY TOP1: 3.75% (19/507)
# currency.txt:
# ACCURACY TOP1: 0.00% (0/28)
# city-in-state.txt:
# ACCURACY TOP1: 1.83% (10/545)
# family.txt:
# ACCURACY TOP1: 28.36% (97/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 57.27% (465/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 59.09% (299/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 59.83% (797/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 60.85% (460/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 66.94% (664/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 53.24% (452/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 33.47% (496/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 68.06% (633/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 59.13% (447/756)
# [8.20543093270366, 7.43801652892562, 8.20543093270366, 8.382526564344746, 8.20543093270366]
# [57.136066547831255, 57.74212715389186, 56.36363636363637, 55.8407605466429, 56.007130124777184]
# [48.93659115639529, 49.31249381739045, 48.293599762587796, 47.8880205757246, 47.99683450390741]
# The code run 43m 4s

# %%
import matplotlib.pyplot as plt
#等差数列。
x = [2,4,6,8,10]
yw1 = [Semantic for Semantic in Sem_win_ftsg]
yw2 = [Syntactic for Syntactic in Syn_win_ftsg]
yw3 = [Total for Total in Tot_win_ftsg]
plt.plot(x,yw1,'rs-',markersize =5,label = 'Semantic')
plt.plot(x,yw2,'m-',markersize =5,label = 'Syntactic')
plt.plot(x,yw3,'k-',markersize =5,label = 'Total')
plt.xlabel('Window Size')
plt.ylabel('Accuracy[%]')
plt.title('The relationship between window size and semantics')
plt.legend()
plt.show()

# %%
W1,vocab1,W1_norm = open_files(vectors_wv_cbow) #vectors_wv_sg  #vectors_ft_sg #vectors_ft_cbow
W2,vocab2,W2_norm = open_files(vectors_wv_sg) #vectors_wv_sg  #vectors_ft_sg #vectors_ft_cbow
W3,vocab3,#  x是epoch y是f1 测试集  command+/
import matplotlib.pyplot as plt
x = [epoch for epoch in range(total_epoch)]
y7 = [f1 for f1 in line_lr[6]]

plt.plot(x,y1,'rs-',markersize =3,label = 'lr=1') # 那个点  红色尺寸点

plt.xlabel('epoch')
plt.ylabel('f1')
plt.title('F1 cases at different learning rates.')
plt.legend() #让标签显示出来
plt.show()
# precision: TP/(TP+FP)
#recallW3_norm = open_files(vectors_ft_sg) #vectors_wv_sg  #vectors_ft_sg #vectors_ft_cbow
W4,vocab4,W4_norm = open_files(vectors_ft_cbow) #vectors_wv_sg  #vectors_ft_sg #vectors_ft_cbow

# %%
import torch
torch.save({
    'correct_sem': correct_sem, 
    'correct_syn': correct_syn,
    'correct_tot': correct_tot,
    'count_sem': count_sem,
    'count_syn': count_syn,
    'count_tot': count_tot,
    'full_count': full_count   
    }, 'w2v_sg.PATH')   #'w2v_cbow.PATH' ; 'w2v_sg.PATH' ;'ft_sg.PATH' ; 'ft_cbow.PATH'

# %%
import torch
data_w2v_cbow = torch.load('w2v_cbow.PATH')
PP = data_w2v_cbow['correct_sem'] #19
LL = data_w2v_cbow['correct_syn'] #0.6927
P2 = data_w2v_cbow['count_sem']   #tensor([0, 1, 0,  ..., 0, 1, 0])

print(PP)
print(LL)
print(P2)

# %%
import torch
torch.save({
    'correct_sem': correct_sem, 
    'correct_syn': correct_syn,
    'correct_tot': correct_tot,
    'count_sem': count_sem,
    'count_syn': count_syn,
    'count_tot': count_tot,
    'full_count': full_count   
    }, 'w2v_sg.PATH')   #'w2v_cbow.PATH' ; 'w2v_sg.PATH' ;'ft_sg.PATH' ; 'ft_cbow.PATH'

# %%
import torch
data_w2v_sg = torch.load('w2v_sg.PATH')
PP = data_w2v_sg['correct_sem'] #19
LL = data_w2v_sg['correct_syn'] #0.6927
P2 = data_w2v_sg['count_sem']   #tensor([0, 1, 0,  ..., 0, 1, 0])

print(PP)
print(LL)
print(P2)

# %%
import torch
torch.save({
    'correct_sem': correct_sem, 
    'correct_syn': correct_syn,
    'correct_tot': correct_tot,
    'count_sem': count_sem,
    'count_syn': count_syn,
    'count_tot': count_tot,
    'full_count': full_count   
    }, 'ft_sg.PATH')   #'w2v_cbow.PATH' ; 'w2v_sg.PATH' ;'ft_sg.PATH' ; 'ft_cbow.PATH'

# %%
import torch
data_ft_sg = torch.load('ft_sg.PATH')
PP = data_ft_sg['correct_sem'] #19
LL = data_ft_sg['correct_syn'] #0.6927
P2 = data_ft_sg['count_sem']   #tensor([0, 1, 0,  ..., 0, 1, 0])

print(PP)
print(LL)
print(P2)

# %%
import torch
torch.save({
    'correct_sem': correct_sem, 
    'correct_syn': correct_syn,
    'correct_tot': correct_tot,
    'count_sem': count_sem,
    'count_syn': count_syn,
    'count_tot': count_tot,
    'full_count': full_count   
    }, 'ft_cbow.PATH')   #'w2v_cbow.PATH' ; 'w2v_sg.PATH' ;'ft_sg.PATH' ; 'ft_cbow.PATH'

# %%
import torch
data_ft_cbow = torch.load('ft_cbow.PATH')
PP = data_ft_cbow['correct_sem'] #19
LL = data_ft_cbow['correct_syn'] #0.6927
P2 = data_ft_cbow['count_sem']   #tensor([0, 1, 0,  ..., 0, 1, 0])

print(PP)
print(LL)
print(P2)

# %%
Sem_wvsg, Syn_wvsg, Tot_wvsy = size_change(FastText,1)
# Out:
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 1.47% (4/272)
# capital-world.txt:
# ACCURACY TOP1: 2.37% (12/507)
# currency.txt:
# ACCURACY TOP1: 0.00% (0/28)
# city-in-state.txt:
# ACCURACY TOP1: 2.20% (12/545)
# family.txt:
# ACCURACY TOP1: 34.80% (119/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 71.67% (582/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 77.47% (392/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 79.28% (1056/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 82.80% (626/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 81.35% (807/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 40.64% (345/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 37.38% (554/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 70.97% (660/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 70.11% (530/756)
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 0.74% (2/272)
# capital-world.txt:
# ACCURACY TOP1: 1.97% (10/507)
# currency.txt:
# ACCURACY TOP1: 0.00% (0/28)
# city-in-state.txt:
# ACCURACY TOP1: 1.10% (6/545)
# family.txt:
# ACCURACY TOP1: 29.53% (101/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 77.71% (631/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 86.36% (437/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 81.08% (1080/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 90.08% (681/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 79.03% (784/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 53.83% (457/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 37.72% (559/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 76.34% (710/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 76.98% (582/756)
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 1.10% (3/272)
# capital-world.txt:
# ACCURACY TOP1: 2.37% (12/507)
# currency.txt:
# ACCURACY TOP1: 0.00% (0/28)
# city-in-state.txt:
# ACCURACY TOP1: 2.20% (12/545)
# family.txt:
# ACCURACY TOP1: 30.12% (103/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 81.16% (659/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 85.57% (433/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 83.11% (1107/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 93.52% (707/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 78.73% (781/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 55.83% (474/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 35.56% (527/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 73.66% (685/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 78.84% (596/756)
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 1.10% (3/272)
# capital-world.txt:
# ACCURACY TOP1: 1.97% (10/507)
# currency.txt:
# ACCURACY TOP1: 0.00% (0/28)
# city-in-state.txt:
# ACCURACY TOP1: 1.65% (9/545)
# family.txt:
# ACCURACY TOP1: 25.15% (86/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 77.96% (633/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 86.17% (436/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 83.63% (1114/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 91.93% (695/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 80.04% (794/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 56.07% (476/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 34.14% (506/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 75.05% (698/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 80.16% (606/756)
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 1.47% (4/272)
# capital-world.txt:
# ACCURACY TOP1: 2.17% (11/507)
# currency.txt:
# ACCURACY TOP1: 0.00% (0/28)
# city-in-state.txt:
# ACCURACY TOP1: 3.67% (20/545)
# family.txt:
# ACCURACY TOP1: 28.36% (97/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 79.43% (645/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 86.17% (436/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 82.28% (1096/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 91.93% (695/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 80.44% (798/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 53.59% (455/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 33.27% (493/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 72.47% (674/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 81.35% (615/756)
# Vocab size:  21613
# capital-common-countries.txt:
# ACCURACY TOP1: 1.10% (3/272)
# capital-world.txt:
# ACCURACY TOP1: 1.78% (9/507)
# currency.txt:
# ACCURACY TOP1: 0.00% (0/28)
# city-in-state.txt:
# ACCURACY TOP1: 1.65% (9/545)
# family.txt:
# ACCURACY TOP1: 28.07% (96/342)
# gram1-adjective-to-adverb.txt:
# ACCURACY TOP1: 79.31% (644/812)
# gram2-opposite.txt:
# ACCURACY TOP1: 86.56% (438/506)
# gram3-comparative.txt:
# ACCURACY TOP1: 80.41% (1071/1332)
# gram4-superlative.txt:
# ACCURACY TOP1: 91.93% (695/756)
# gram5-present-participle.txt:
# ACCURACY TOP1: 79.13% (785/992)
# gram6-nationality-adjective.txt:
# ACCURACY TOP1: 54.89% (466/849)
# gram7-past-tense.txt:
# ACCURACY TOP1: 35.63% (528/1482)
# gram8-plural.txt:
# ACCURACY TOP1: 73.01% (679/930)
# gram9-plural-verbs.txt:
# ACCURACY TOP1: 79.37% (600/756)
